# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/songs.csv", index_col=0)
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'TrackName', 'Artist', 'maxStreams',
#        'avgStreams', 'accumulated_streams', 'top1', 'timesTop10', 'timesTop25',
#        'timesTop50', 'timesTop100', 'timesTop200', 'weeksTop10', 'weeksTop25',
#        'weeksTop50', 'weeksTop100', 'weeksTop200'],
#       dtype='object')

# %%
df.head()
df.tail()
# Out:
#                         danceability  energy  key  loudness  mode  \
# id
# 32h6yQGn4oAhZ0HRsTMX26         0.622   0.800    5    -5.819     1
# 1CCDIow4pPYyJYzhtTUYz2         0.874   0.714    5    -4.946     1
# 6wyr4ReB05D9sJB1Rsmcqo         0.826   0.817    2    -4.081     1
# 2FvD20Z8aoWIePi7PoN8sG         0.816   0.582    8    -4.141     1
# 7lnQCEtaDJeMZN75siSxLc         0.721   0.647   11    -7.039     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 32h6yQGn4oAhZ0HRsTMX26       0.0425       0.05050          0.000000    0.0619
# 1CCDIow4pPYyJYzhtTUYz2       0.2330       0.02730          0.000000    0.3560
# 6wyr4ReB05D9sJB1Rsmcqo       0.0921       0.00502          0.000011    0.2940
# 2FvD20Z8aoWIePi7PoN8sG       0.3410       0.07940          0.000006    0.0916
# 7lnQCEtaDJeMZN75siSxLc       0.1890       0.05130          0.002600    0.2000
#
#                         valence  ...  timesTop10  timesTop25  timesTop50  \
# ...

# %%
description = df.describe()
description
# Out:
#        danceability       energy          key     loudness         mode  \
# count   2748.000000  2748.000000  2748.000000  2748.000000  2748.000000
# mean       0.686806     0.635037     5.280204    -6.289332     0.579330
# std        0.140545     0.165572     3.666486     2.586431     0.493756
# min        0.153000     0.027900     0.000000   -34.475000     0.000000
# 25%        0.602000     0.534000     1.000000    -7.391250     0.000000
# 50%        0.703000     0.651000     6.000000    -5.869000     1.000000
# 75%        0.785250     0.759250     8.000000    -4.630000     1.000000
# max        0.974000     0.978000    11.000000     0.175000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  2748.000000   2748.000000       2748.000000  2748.000000  2748.000000
# mean      0.130943      0.223116          0.009223     0.176039     0.481979
# std       0.120168      0.236199          0.059728     0.132828     0.220715
# ...

# %%
pd.isnull(df).sum()

print("veo que algunas filas tienen null en trackname y artist, esto es raro por que traje esa info de la app de spotify, para revisar las filas exactas hago:")
null_columns=df.columns[df.isnull().any()]
df[df["TrackName"].isnull()][null_columns]
df[df["Artist"].isnull()][null_columns]
print("observando en la pagina: https://spotifycharts.com/regional/global/weekly/2017-07-14--2017-07-21 se puede ver que las canciones no tiene nombre ni artista, y ya vienen asi desde spotify")
print("por el momento estas filas no seran eliminadas ya que no creo que utilize el tranckname ni artist para crear el modelo, pero lo tendre en cuenta en caso de que si")
# Out:
# veo que algunas filas tienen null en trackname y artist, esto es raro por que traje esa info de la app de spotify, para revisar las filas exactas hago:
# observando en la pagina: https://spotifycharts.com/regional/global/weekly/2017-07-14--2017-07-21 se puede ver que las canciones no tiene nombre ni artista, y ya vienen asi desde spotify
# por el momento estas filas no seran eliminadas ya que no creo que utilize el tranckname ni artist para crear el modelo, pero lo tendre en cuenta en caso de que si

# %%
sns.distplot(df['top1']).set_title('Distribution of TOP1')
# Out:
# Text(0.5, 1.0, 'Distribution of TOP1')

# %%
sns.distplot(df['timesTop10']).set_title('Distribution of TOP10')
description.timesTop10
# Out:
# count    2748.000000
# mean        0.487627
# std         2.212795
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        24.000000
# Name: timesTop10, dtype: float64

# %%
sns.distplot(df['timesTop25']).set_title('Distribution of TOP25')
description.timesTop25
# Out:
# count    2748.000000
# mean        0.731441
# std         2.332078
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        23.000000
# Name: timesTop25, dtype: float64

# %%
sns.distplot(df['timesTop50']).set_title('Distribution of TOP50')
description.timesTop50
# Out:
# count    2748.000000
# mean        1.219068
# std         3.025322
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        25.000000
# Name: timesTop50, dtype: float64

# %%
sns.distplot(df['timesTop100']).set_title('Distribution of TOP100')
description.timesTop100
# Out:
# count    2748.000000
# mean        2.438137
# std         4.900112
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         3.000000
# max        66.000000
# Name: timesTop100, dtype: float64

# %%
sns.distplot(df['timesTop200']).set_title('Distribution of TOP200')
description.timesTop200
# Out:
# count    2748.000000
# mean        4.876274
# std         8.550753
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         6.000000
# max       116.000000
# Name: timesTop200, dtype: float64

# %%
sns.heatmap(df.corr()).set_title("Correlation between all variables")
print("Se puede apreciar correlacion entre las variables creadas ej: avgStreams-maxStreams")
print("Pero no mucha entre la metadata de la canciones y las variables creadas ej: danceability-top10")
# Out:
# Se puede apreciar correlacion entre las variables creadas ej: avgStreams-maxStreams
# Pero no mucha entre la metadata de la cancio y las variables creadas ej: danceability-top10

# %%
#sns.pairplot(df)

# %%
df_rows_top1 = df.drop(['timesTop10','timesTop25','timesTop50','timesTop100','timesTop200','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
#df_rows_top1 = df_rows_top1.loc[df['top1'] == True]

df_rows_top10 = df.drop(['top1','timesTop25','timesTop50','timesTop100','timesTop200','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
#df_rows_top10 = df_rows_top10.loc[df['timesTop10'] > 0]

df_rows_top25 = df.drop(['timesTop10','top1','timesTop50','timesTop100','timesTop200','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
df_rows_top25 = df_rows_top25.loc[df['timesTop25'] > 0]

df_rows_top50 = df.drop(['timesTop10','timesTop25','top1','timesTop100','timesTop200','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
df_rows_top50 = df_rows_top50.loc[df['timesTop50'] > 0]

df_rows_top100 = df.drop(['timesTop10','timesTop25','timesTop50','top1','timesTop200','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
df_rows_top100 = df_rows_top100.loc[df['timesTop100'] > 0]

df_rows_top200 = df.drop(['timesTop10','timesTop25','timesTop50','timesTop100','top1','weeksTop10', 'weeksTop25',
       'weeksTop50', 'weeksTop100', 'weeksTop200',  'maxStreams','avgStreams', 'TrackName','accumulated_streams'],axis=1)
df_rows_top200 = df_rows_top200.loc[df['timesTop200'] > 0]

# %%
print("There are {0} songs in top 1".format(len(df.loc[df['top1'] == True])))
print("There are {0} songs in top 10".format(len(df.loc[df['timesTop10'] > 0])))
print("There are {0} songs in top 25".format(len(df.loc[df['timesTop25'] > 0])))
print("There are {0} songs in top 50".format(len(df.loc[df['timesTop50'] > 0])))
print("There are {0} songs in top 100".format(len(df.loc[df['timesTop100'] > 0])))
print("There are {0} songs in top 200".format(len(df.loc[df['timesTop200'] > 0])))
# Out:
# There are 33 songs in top 1
# There are 244 songs in top 10
# There are 482 songs in top 25
# There are 767 songs in top 50
# There are 1345 songs in top 100
# There are 2355 songs in top 200

# %%
print("Pairplot between top1 variable and all others")
sns.pairplot(df_rows_top1, x_vars=["top1"], y_vars=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature', 'Artist'])
# Out:
# Pairplot between top1 variable and all others
# There are 2748 songs in this top

# %%
print("Pairplot between top10 variable and all others")
sns.pairplot(df_rows_top10, x_vars=["timesTop10"], y_vars=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature', 'Artist'])
# Out:
# Pairplot between top10 variable and all others
